# %%
#1.a
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torch.optim as optim
import torchvision.datasets as datasets
import imageio
import numpy as np
import matplotlib
from torchvision.utils import make_grid, save_image
from torch.utils.data import DataLoader
from matplotlib import pyplot as plt
from tqdm import tqdm

# %% [markdown]
# # Define learning parameters

# %%
# learning parameters
batch_size = 512
epochs = 100
sample_size = 64 # fixed sample size for generator
nz = 128 # latent vector size
k = 1 # number of steps to apply to the discriminator
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Prepare training dataset

# %%
transform = transforms.Compose([
                                transforms.ToTensor(),
                                transforms.Normalize((0.5,),(0.5,)),
])
to_pil_image = transforms.ToPILImage()

# Make input, output folders
# !mkdir -p input
# !mkdir -p outputs

# Load train data
train_data = datasets.MNIST(
    root='input/data',
    train=True,
    download=True,
    transform=transform
)
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to input/data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|████████████████████████████| 9912422/9912422 [00:01<00:00, 9273323.21it/s]
# Extracting input/data/MNIST/raw/train-images-idx3-ubyte.gz to input/data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to input/data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|████████████████████████████████| 28881/28881 [00:00<00:00, 6592418.71it/s]
# Extracting input/data/MNIST/raw/train-labels-idx1-ubyte.gz to input/data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to input/data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|████████████████████████████| 1648877/1648877 [00:00<00:00, 6677510.93it/s]
# Extracting input/data/MNIST/raw/t10k-images-idx3-ubyte.gz to input/data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to input/data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|█████████████████████████████████| 4542/4542 [00:00<00:00, 12370473.23it/s]
# Extracting input/data/MNIST/raw/t10k-labels-idx1-ubyte.gz to input/data/MNIST/raw

# %% [markdown]
# # Generator

# %%
class Generator(nn.Module):
    def __init__(self, nz):
        super(Generator, self).__init__()
        self.nz = nz
        self.main = nn.Sequential(
            nn.Linear(self.nz, 256),
            nn.LeakyReLU(0.2),
            nn.Linear(256, 512),
            nn.LeakyReLU(0.2),
            nn.Linear(512, 1024),
            nn.LeakyReLU(0.2),
            nn.Linear(1024, 784),
            nn.Tanh(),
        )
    def forward(self, x):
        return self.main(x).view(-1, 1, 28, 28)

# %% [markdown]
# # Discriminator

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.n_input = 784
        self.main = nn.Sequential(
            nn.Linear(self.n_input, 1024),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(1024, 512),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(256, 1),
            nn.Sigmoid(),
        )
    def forward(self, x):
        x = x.view(-1, 784)
        return self.main(x)

# %%
generator = Generator(nz).to(device)
discriminator = Discriminator().to(device)
print('##### GENERATOR #####')
print(generator)
print('######################')
print('\n##### DISCRIMINATOR #####')
print(discriminator)
print('######################')
# Out:
# ##### GENERATOR #####
# Generator(
#   (main): Sequential(
#     (0): Linear(in_features=128, out_features=256, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Linear(in_features=256, out_features=512, bias=True)
#     (3): LeakyReLU(negative_slope=0.2)
#     (4): Linear(in_features=512, out_features=1024, bias=True)
#     (5): LeakyReLU(negative_slope=0.2)
#     (6): Linear(in_features=1024, out_features=784, bias=True)
#     (7): Tanh()
#   )
# )
# ######################
#
# ##### DISCRIMINATOR #####
# Discriminator(
#   (main): Sequential(
#     (0): Linear(in_features=784, out_features=1024, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=1024, out_features=512, bias=True)
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Dropout(p=0.3, inplace=False)
#     (6): Linear(in_features=512, out_features=256, bias=True)
#     (7): LeakyReLU(negative_slope=0.2)
#     (8): Dropout(p=0.3, inplace=False)
#     (9): Linear(in_features=256, out_features=1, bias=True)
#     (10): Sigmoid()
#   )
# )
# ######################

# %% [markdown]
# # Tools for training

# %%
# optimizers
optim_g = optim.Adam(generator.parameters(), lr=0.0002)
optim_d = optim.Adam(discriminator.parameters(), lr=0.0002)

# %%
# loss function
criterion = nn.BCELoss() # Binary Cross Entropy loss

# %%
losses_g = [] # to store generator loss after each epoch
losses_d = [] # to store discriminator loss after each epoch
images = [] # to store images generatd by the generator

# %%
# to create real labels (1s)
def label_real(size):
    data = torch.ones(size, 1)
    return data.to(device)
# to create fake labels (0s)
def label_fake(size):
    data = torch.zeros(size, 1)
    return data.to(device)

# %%
# function to create the noise vector
def create_noise(sample_size, nz):
    return torch.randn(sample_size, nz).to(device)

# %%
# to save the images generated by the generator
def save_generator_image(image, path):
    save_image(image, path)

# %%
# create the noise vector - fixed to track how GAN is trained.
noise = create_noise(sample_size, nz)

# %% [markdown]
# # Q. Write training loop

# %%
torch.manual_seed(7)

def generator_loss(output, true_label):
    ############ YOUR CODE HERE ##########
    optim_g.zero_grad()
    batch =  output.shape[0]
    
    z = create_noise(batch, 128)
    labelz = label_real(batch)
    xfake = generator(z)
    outz = discriminator(xfake)
    lossz = criterion(outz, labelz)

    Gloss = lossz
    Gloss.backward()
    optim_g.step()

    return  Gloss.data.item()
    
    
    
    ######################################
    
def discriminator_loss(output, true_label):
    ############ YOUR CODE HERE ##########
    optim_d.zero_grad()
    batch =  output.shape[0]
    
    labelx = label_real(batch)
    
    outx = discriminator(output)
    lossx = criterion(outx, labelx)

    z = create_noise(batch, 128)
    labelz = label_fake(batch)
    
    xfake = generator(z)
    outz = discriminator(xfake)
    lossz = criterion(outz, labelz)

    Dloss = lossx + lossz

    Dloss.backward()
    optim_d.step()

    return  Dloss.data.item()
    
    
    ######################################
    

for epoch in range(epochs):
    loss_g = 0.0
    loss_d = 0.0
    for bi, data in tqdm(enumerate(train_loader), total=int(len(train_data)/train_loader.batch_size)):
        ############ YOUR CODE HERE ########## 
        for _ in range(k):
            data_ = data[0][torch.randperm(data[0].size()[0])]
            data_ = data_[:sample_size, :, :, :]
            loss_d += discriminator_loss(data_, None)
        loss_g += generator_loss(data_, None)
    
        ######################################
    
    
    # create the final fake image for the epoch
    generated_img = generator(noise).cpu().detach()
    
    # make the images as grid
    generated_img = make_grid(generated_img)
    
    # visualize generated images
    if (epoch + 1) % 5 == 0:
        plt.imshow(generated_img.permute(1, 2, 0))
        plt.title(f'epoch {epoch+1}')
        plt.axis('off')
        plt.show()
    
    # save the generated torch tensor models to disk
    save_generator_image(generated_img, f"outputs/gen_img{epoch+1}.png")
    images.append(generated_img)
    epoch_loss_g = loss_g / bi # total generator loss for the epoch
    epoch_loss_d = loss_d / bi # total discriminator loss for the epoch
    losses_g.append(epoch_loss_g)
    losses_d.append(epoch_loss_d)
    
    print(f"Epoch {epoch+1} of {epochs}")
    print(f"Generator loss: {epoch_loss_g:.8f}, Discriminator loss: {epoch_loss_d:.8f}")
# Out:
# 118it [00:04, 25.14it/s]
# Epoch 1 of 100
# Generator loss: 1.68232294, Discriminator loss: 0.88473576
# 118it [00:04, 23.74it/s]
# Epoch 2 of 100
# Generator loss: 1.60911716, Discriminator loss: 0.97754692
# 118it [00:04, 24.08it/s]
# Epoch 3 of 100
# Generator loss: 1.54496824, Discriminator loss: 0.94341898
# 118it [00:04, 26.95it/s]
# Epoch 4 of 100
# Generator loss: 1.56166111, Discriminator loss: 0.94212364
# 118it [00:04, 26.70it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 5 of 100
# Generator loss: 1.61166885, Discriminator loss: 0.92420496
# 118it [00:05, 23.10it/s]
# Epoch 6 of 100
# Generator loss: 1.58508767, Discriminator loss: 0.93100185
# 118it [00:05, 22.96it/s]
# Epoch 7 of 100
# Generator loss: 1.61889900, Discriminator loss: 0.92650560
# 118it [00:05, 22.82it/s]
# Epoch 8 of 100
# Generator loss: 1.59297668, Discriminator loss: 0.92769763
# 118it [00:05, 22.96it/s]
# Epoch 9 of 100
# Generator loss: 1.65446959, Discriminator loss: 0.90326722
# 118it [00:05, 22.38it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 10 of 100
# Generator loss: 1.61226350, Discriminator loss: 0.93238890
# 118it [00:05, 22.22it/s]
# Epoch 11 of 100
# Generator loss: 1.59728130, Discriminator loss: 0.97602423
# 118it [00:05, 23.47it/s]
# Epoch 12 of 100
# Generator loss: 1.63737861, Discriminator loss: 0.93138226
# 118it [00:04, 26.11it/s]
# Epoch 13 of 100
# Generator loss: 1.57656085, Discriminator loss: 0.92724001
# 118it [00:04, 24.48it/s]
# Epoch 14 of 100
# Generator loss: 1.59370246, Discriminator loss: 0.90927663
# 118it [00:04, 24.06it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 15 of 100
# Generator loss: 1.58774156, Discriminator loss: 0.96438986
# 118it [00:04, 25.90it/s]
# Epoch 16 of 100
# Generator loss: 1.56918803, Discriminator loss: 0.93243407
# 118it [00:05, 21.25it/s]
# Epoch 17 of 100
# Generator loss: 1.59572309, Discriminator loss: 0.94511013
# 118it [00:05, 23.51it/s]
# Epoch 18 of 100
# Generator loss: 1.59570478, Discriminator loss: 0.93512510
# 118it [00:04, 23.80it/s]
# Epoch 19 of 100
# Generator loss: 1.54332584, Discriminator loss: 0.95789193
# 118it [00:05, 23.19it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 20 of 100
# Generator loss: 1.58357558, Discriminator loss: 0.93788053
# 118it [00:04, 23.61it/s]
# Epoch 21 of 100
# Generator loss: 1.52109378, Discriminator loss: 0.95540929
# 118it [00:05, 22.46it/s]
# Epoch 22 of 100
# Generator loss: 1.48749872, Discriminator loss: 1.01594549
# 118it [00:04, 23.62it/s]
# Epoch 23 of 100
# Generator loss: 1.44146980, Discriminator loss: 1.04489615
# 118it [00:05, 22.76it/s]
# Epoch 24 of 100
# Generator loss: 1.37687136, Discriminator loss: 1.05064343
# 118it [00:04, 24.70it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 25 of 100
# Generator loss: 1.42550410, Discriminator loss: 1.02360819
# 118it [00:04, 24.04it/s]
# Epoch 26 of 100
# Generator loss: 1.58126173, Discriminator loss: 0.97758366
# 118it [00:04, 24.14it/s]
# Epoch 27 of 100
# Generator loss: 1.41241533, Discriminator loss: 1.01214005
# 118it [00:04, 24.24it/s]
# Epoch 28 of 100
# Generator loss: 1.37805674, Discriminator loss: 1.00653637
# 118it [00:05, 23.37it/s]
# Epoch 29 of 100
# Generator loss: 1.43616334, Discriminator loss: 0.98334829
# 118it [00:04, 26.70it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 30 of 100
# Generator loss: 1.52941547, Discriminator loss: 0.97988387
# 118it [00:04, 26.28it/s]
# Epoch 31 of 100
# Generator loss: 1.48391294, Discriminator loss: 0.99114884
# 118it [00:04, 25.75it/s]
# Epoch 32 of 100
# Generator loss: 1.47699930, Discriminator loss: 0.98299834
# 118it [00:04, 25.55it/s]
# Epoch 33 of 100
# Generator loss: 1.43752564, Discriminator loss: 1.01864211
# 118it [00:04, 25.21it/s]
# Epoch 34 of 100
# Generator loss: 1.49115897, Discriminator loss: 0.98832458
# 118it [00:04, 23.91it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 35 of 100
# Generator loss: 1.45442612, Discriminator loss: 1.00745421
# 118it [00:04, 24.30it/s]
# Epoch 36 of 100
# Generator loss: 1.41142826, Discriminator loss: 0.99897043
# 118it [00:04, 24.08it/s]
# Epoch 37 of 100
# Generator loss: 1.39867225, Discriminator loss: 1.02784938
# 118it [00:04, 24.73it/s]
# Epoch 38 of 100
# Generator loss: 1.34575685, Discriminator loss: 1.04266567
# 118it [00:04, 24.41it/s]
# Epoch 39 of 100
# Generator loss: 1.39057361, Discriminator loss: 1.01637187
# 118it [00:04, 24.15it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 40 of 100
# Generator loss: 1.39171616, Discriminator loss: 1.03444888
# 118it [00:04, 24.58it/s]
# Epoch 41 of 100
# Generator loss: 1.39423111, Discriminator loss: 1.06278955
# 118it [00:04, 24.02it/s]
# Epoch 42 of 100
# Generator loss: 1.34085229, Discriminator loss: 1.05356708
# 118it [00:04, 25.52it/s]
# Epoch 43 of 100
# Generator loss: 1.40366717, Discriminator loss: 1.02170415
# 118it [00:04, 25.00it/s]
# Epoch 44 of 100
# Generator loss: 1.30270546, Discriminator loss: 1.08128923
# 118it [00:04, 24.20it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 45 of 100
# Generator loss: 1.36601846, Discriminator loss: 1.03098803
# 118it [00:04, 26.40it/s]
# Epoch 46 of 100
# Generator loss: 1.34653555, Discriminator loss: 1.03974310
# 118it [00:04, 25.44it/s]
# Epoch 47 of 100
# Generator loss: 1.37687079, Discriminator loss: 1.04206054
# 118it [00:04, 24.51it/s]
# Epoch 48 of 100
# Generator loss: 1.32308436, Discriminator loss: 1.04971576
# 118it [00:04, 25.73it/s]
# Epoch 49 of 100
# Generator loss: 1.34363899, Discriminator loss: 1.03802321
# 118it [00:04, 26.52it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 50 of 100
# Generator loss: 1.37877677, Discriminator loss: 1.03834606
# 118it [00:04, 23.73it/s]
# Epoch 51 of 100
# Generator loss: 1.41433624, Discriminator loss: 1.02307639
# 118it [00:04, 25.75it/s]
# Epoch 52 of 100
# Generator loss: 1.29598769, Discriminator loss: 1.05020691
# 118it [00:04, 24.54it/s]
# Epoch 53 of 100
# Generator loss: 1.43440226, Discriminator loss: 1.05309228
# 118it [00:04, 24.50it/s]
# Epoch 54 of 100
# Generator loss: 1.48651427, Discriminator loss: 1.00101580
# 118it [00:04, 24.08it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 55 of 100
# Generator loss: 1.28873633, Discriminator loss: 1.07562896
# 118it [00:04, 24.82it/s]
# Epoch 56 of 100
# Generator loss: 1.38331569, Discriminator loss: 1.01405756
# 118it [00:04, 25.24it/s]
# Epoch 57 of 100
# Generator loss: 1.44456903, Discriminator loss: 1.06029982
# 118it [00:04, 24.63it/s]
# Epoch 58 of 100
# Generator loss: 1.36145912, Discriminator loss: 1.03543538
# 118it [00:04, 26.04it/s]
# Epoch 59 of 100
# Generator loss: 1.35735773, Discriminator loss: 1.04258494
# 118it [00:04, 25.20it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 60 of 100
# Generator loss: 1.26576990, Discriminator loss: 1.07766872
# 118it [00:05, 22.94it/s]
# Epoch 61 of 100
# Generator loss: 1.31009233, Discriminator loss: 1.04058024
# 118it [00:04, 26.40it/s]
# Epoch 62 of 100
# Generator loss: 1.35451385, Discriminator loss: 1.04866437
# 118it [00:04, 26.51it/s]
# Epoch 63 of 100
# Generator loss: 1.25609337, Discriminator loss: 1.08552031
# 118it [00:04, 24.68it/s]
# Epoch 64 of 100
# Generator loss: 1.33203894, Discriminator loss: 1.06924641
# 118it [00:04, 25.04it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 65 of 100
# Generator loss: 1.35561027, Discriminator loss: 1.05626551
# 118it [00:04, 24.20it/s]
# Epoch 66 of 100
# Generator loss: 1.26206420, Discriminator loss: 1.06789109
# 118it [00:04, 24.40it/s]
# Epoch 67 of 100
# Generator loss: 1.29342948, Discriminator loss: 1.08392666
# 118it [00:04, 24.84it/s]
# Epoch 68 of 100
# Generator loss: 1.26678354, Discriminator loss: 1.08935886
# 118it [00:05, 22.56it/s]
# Epoch 69 of 100
# Generator loss: 1.27562376, Discriminator loss: 1.06374403
# 118it [00:04, 26.72it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 70 of 100
# Generator loss: 1.27183521, Discriminator loss: 1.08929255
# 118it [00:04, 24.57it/s]
# Epoch 71 of 100
# Generator loss: 1.30760986, Discriminator loss: 1.05767261
# 118it [00:04, 26.87it/s]
# Epoch 72 of 100
# Generator loss: 1.30656190, Discriminator loss: 1.06924053
# 118it [00:05, 23.49it/s]
# Epoch 73 of 100
# Generator loss: 1.34354973, Discriminator loss: 1.05231659
# 118it [00:04, 25.29it/s]
# Epoch 74 of 100
# Generator loss: 1.27625548, Discriminator loss: 1.08548440
# 118it [00:04, 25.36it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 75 of 100
# Generator loss: 1.30088252, Discriminator loss: 1.07653800
# 118it [00:04, 25.40it/s]
# Epoch 76 of 100
# Generator loss: 1.32832423, Discriminator loss: 1.06032472
# 118it [00:04, 25.91it/s]
# Epoch 77 of 100
# Generator loss: 1.27387539, Discriminator loss: 1.06205891
# 118it [00:04, 26.18it/s]
# Epoch 78 of 100
# Generator loss: 1.28087114, Discriminator loss: 1.09464512
# 118it [00:04, 24.69it/s]
# Epoch 79 of 100
# Generator loss: 1.29102785, Discriminator loss: 1.09175537
# 118it [00:04, 24.15it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 80 of 100
# Generator loss: 1.31128249, Discriminator loss: 1.06994027
# 118it [00:04, 24.16it/s]
# Epoch 81 of 100
# Generator loss: 1.30291550, Discriminator loss: 1.05422774
# 118it [00:04, 24.47it/s]
# Epoch 82 of 100
# Generator loss: 1.32303837, Discriminator loss: 1.05771622
# 118it [00:04, 25.25it/s]
# Epoch 83 of 100
# Generator loss: 1.25617096, Discriminator loss: 1.10725812
# 118it [00:04, 23.60it/s]
# Epoch 84 of 100
# Generator loss: 1.25149922, Discriminator loss: 1.08924068
# 118it [00:04, 25.82it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 85 of 100
# Generator loss: 1.19567682, Discriminator loss: 1.11107959
# 118it [00:04, 24.11it/s]
# Epoch 86 of 100
# Generator loss: 1.26112305, Discriminator loss: 1.10397103
# 118it [00:04, 25.37it/s]
# Epoch 87 of 100
# Generator loss: 1.22198465, Discriminator loss: 1.11128002
# 118it [00:04, 26.32it/s]
# Epoch 88 of 100
# Generator loss: 1.33454590, Discriminator loss: 1.05882664
# 118it [00:04, 26.04it/s]
# Epoch 89 of 100
# Generator loss: 1.23521993, Discriminator loss: 1.10344610
# 118it [00:04, 26.01it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 90 of 100
# Generator loss: 1.32200591, Discriminator loss: 1.06846334
# 118it [00:04, 26.58it/s]
# Epoch 91 of 100
# Generator loss: 1.20733478, Discriminator loss: 1.12539604
# 118it [00:04, 26.76it/s]
# Epoch 92 of 100
# Generator loss: 1.26948184, Discriminator loss: 1.09117564
# 118it [00:04, 25.12it/s]
# Epoch 93 of 100
# Generator loss: 1.22432432, Discriminator loss: 1.10720804
# 118it [00:04, 24.77it/s]
# Epoch 94 of 100
# Generator loss: 1.22196018, Discriminator loss: 1.14031517
# 118it [00:04, 24.87it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 95 of 100
# Generator loss: 1.18707426, Discriminator loss: 1.11411713
# 118it [00:04, 25.38it/s]
# Epoch 96 of 100
# Generator loss: 1.21074297, Discriminator loss: 1.10980658
# 118it [00:04, 25.05it/s]
# Epoch 97 of 100
# Generator loss: 1.25313584, Discriminator loss: 1.14607456
# 118it [00:04, 24.27it/s]
# Epoch 98 of 100
# Generator loss: 1.24763227, Discriminator loss: 1.09806155
# 118it [00:04, 24.17it/s]
# Epoch 99 of 100
# Generator loss: 1.23635848, Discriminator loss: 1.10847344
# 118it [00:04, 25.34it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 100 of 100
# Generator loss: 1.19458566, Discriminator loss: 1.11649121

# %%
print('DONE TRAINING')
torch.save(generator.state_dict(), 'outputs/generator.pth')
# Out:
# DONE TRAINING

# %%
# save the generated images as GIF file
imgs = [np.array(to_pil_image(img)) for img in images]
imageio.mimsave('outputs/generator_images.gif', imgs)

# %%
# plot and save the generator and discriminator loss
plt.figure()
plt.plot(losses_g, label='Generator loss')
plt.plot(losses_d, label='Discriminator Loss')
plt.legend()
plt.savefig('outputs/loss.png')

# %%
#1.b
for epoch in range(epochs):
    loss_g = 0.0
    loss_d = 0.0
    for bi, data in tqdm(enumerate(train_loader), total=int(len(train_data)/train_loader.batch_size)):

        x = data[0]

        ### UPDATE DISCRIMINATOR ###
        optim_d.zero_grad() # initialize gradient

        # real pass
        real_output = discriminator.forward(x)
        d_loss_real = discriminator_loss(real_output, label_real(real_output.size()[0]))

        # fake pass
        fake_data = generator.forward(create_noise(sample_size, nz))
        fake_output = discriminator.forward(fake_data)
        d_loss_fake = discriminator_loss(fake_output, label_fake(sample_size))

        loss_D = d_loss_real + d_loss_fake
        loss_D.backward()
        optim_d.step()

        loss_d += loss_D.detach().numpy()

        ### UPDATE GENERATOR ###
        optim_g.zero_grad()

        generated_data = generator.forward(create_noise(sample_size, nz))
        generated_output = discriminator.forward(generated_data)
        loss_G = generator_loss(generated_output, label_real(sample_size)) 
        loss_G.backward()
        optim_g.step()

        loss_g += loss_G.detach().numpy()
        ######################################
    
    
    # create the final fake image for the epoch
    generated_img = generator(noise).cpu().detach()
    
    # make the images as grid
    generated_img = make_grid(generated_img)
    
    # visualize generated images
    if (epoch + 1) % 5 == 0:
        plt.imshow(generated_img.permute(1, 2, 0))
        plt.title(f'epoch {epoch+1}')
        plt.axis('off')
        # plt.show()
    
    # save the generated torch tensor models to disk
    save_generator_image(generated_img, f"output/new_loss_gen_img{epoch+1}.png")
    images.append(generated_img)
    epoch_loss_g = loss_g / bi # total generator loss for the epoch
    epoch_loss_d = loss_d / bi # total discriminator loss for the epoch
    losses_g.append(epoch_loss_g)
    losses_d.append(epoch_loss_d)
    
    print(f"Epoch {epoch+1} of {epochs}")
    print(f"Generator loss: {epoch_loss_g:.8f}, Discriminator loss: {epoch_loss_d:.8f}")

print('DONE TRAINING')
torch.save(generator.state_dict(), 'output/new_loss_generator.pth')

# save the generated images as GIF file
imgs = [np.array(to_pil_image(img)) for img in images]
imageio.mimsave('output/new_loss_generator_images.gif', imgs)

# plot and save the generator and discriminator loss
plt.figure()
plt.plot(losses_g, label='Generator loss')
plt.plot(losses_d, label='Discriminator Loss')
plt.legend()
plt.savefig('output/new_loss_loss.png')


if __name__ == '__main__':
    pass
# Out:
# 118it [00:05, 22.97it/s]
# Epoch 1 of 100
# Generator loss: -0.25012250, Discriminator loss: 0.45185489
# 118it [00:05, 21.32it/s]
# Epoch 2 of 100
# Generator loss: -0.00003886, Discriminator loss: 0.00005972
# 118it [00:05, 21.84it/s]
# Epoch 3 of 100
# Generator loss: -0.00003867, Discriminator loss: 0.00005400
# 118it [00:05, 22.36it/s]
# Epoch 4 of 100
# Generator loss: -0.00003254, Discriminator loss: 0.00004843
# 118it [00:05, 21.49it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 5 of 100
# Generator loss: -0.00003167, Discriminator loss: 0.00004432
# 118it [00:05, 21.79it/s]
# Epoch 6 of 100
# Generator loss: -0.00003546, Discriminator loss: 0.00005167
# 118it [00:05, 23.12it/s]
# Epoch 7 of 100
# Generator loss: -0.00005694, Discriminator loss: 0.00008126
# 118it [00:05, 22.14it/s]
# Epoch 8 of 100
# Generator loss: -0.00067388, Discriminator loss: 0.01764455
# 118it [00:05, 21.38it/s]
# Epoch 9 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 22.08it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 10 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 22.83it/s]
# Epoch 11 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:04, 23.69it/s]
# Epoch 12 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:04, 23.64it/s]
# Epoch 13 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 23.06it/s]
# Epoch 14 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:04, 23.69it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 15 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:04, 23.77it/s]
# Epoch 16 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 23.55it/s]
# Epoch 17 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:04, 23.85it/s]
# Epoch 18 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:04, 23.81it/s]
# Epoch 19 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 23.39it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 20 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:04, 23.91it/s]
# Epoch 21 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:04, 23.87it/s]
# Epoch 22 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 23.57it/s]
# Epoch 23 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 22.21it/s]
# Epoch 24 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 21.82it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 25 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 21.06it/s]
# Epoch 26 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 21.16it/s]
# Epoch 27 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 21.39it/s]
# Epoch 28 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 23.52it/s]
# Epoch 29 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 21.76it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 30 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 23.05it/s]
# Epoch 31 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 23.47it/s]
# Epoch 32 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 23.41it/s]
# Epoch 33 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:04, 23.71it/s]
# Epoch 34 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:04, 23.86it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 35 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 22.39it/s]
# Epoch 36 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:04, 23.85it/s]
# Epoch 37 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:04, 23.85it/s]
# Epoch 38 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 23.36it/s]
# Epoch 39 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 23.27it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 40 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 23.24it/s]
# Epoch 41 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 23.17it/s]
# Epoch 42 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:04, 23.80it/s]
# Epoch 43 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:04, 23.92it/s]
# Epoch 44 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 23.55it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 45 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:04, 23.84it/s]
# Epoch 46 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:04, 23.84it/s]
# Epoch 47 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 22.78it/s]
# Epoch 48 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:04, 24.04it/s]
# Epoch 49 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:04, 24.09it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 50 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:04, 24.05it/s]
# Epoch 51 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:04, 23.93it/s]
# Epoch 52 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:04, 23.95it/s]
# Epoch 53 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 22.32it/s]
# Epoch 54 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 23.48it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 55 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 23.35it/s]
# Epoch 56 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:04, 24.15it/s]
# Epoch 57 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 23.56it/s]
# Epoch 58 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 23.23it/s]
# Epoch 59 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 23.51it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 60 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 23.29it/s]
# Epoch 61 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:04, 23.93it/s]
# Epoch 62 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:04, 23.84it/s]
# Epoch 63 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 23.38it/s]
# Epoch 64 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:04, 23.82it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 65 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:04, 23.77it/s]
# Epoch 66 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 23.51it/s]
# Epoch 67 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 23.27it/s]
# Epoch 68 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:04, 23.92it/s]
# Epoch 69 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:04, 23.91it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 70 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 23.11it/s]
# Epoch 71 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 23.25it/s]
# Epoch 72 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 23.41it/s]
# Epoch 73 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 22.27it/s]
# Epoch 74 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 22.07it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 75 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 20.54it/s]
# Epoch 76 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 21.87it/s]
# Epoch 77 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 22.33it/s]
# Epoch 78 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 22.11it/s]
# Epoch 79 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 22.07it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 80 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 22.19it/s]
# Epoch 81 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 21.85it/s]
# Epoch 82 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 21.77it/s]
# Epoch 83 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 22.24it/s]
# Epoch 84 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 21.85it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 85 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 22.04it/s]
# Epoch 86 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 21.72it/s]
# Epoch 87 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 21.63it/s]
# Epoch 88 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 21.68it/s]
# Epoch 89 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 21.62it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 90 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 22.01it/s]
# Epoch 91 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 21.95it/s]
# Epoch 92 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 22.18it/s]
# Epoch 93 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 21.80it/s]
# Epoch 94 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 22.25it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 95 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 22.11it/s]
# Epoch 96 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 22.42it/s]
# Epoch 97 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 22.16it/s]
# Epoch 98 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 22.18it/s]
# Epoch 99 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# 118it [00:05, 22.46it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 100 of 100
# Generator loss: 0.00000000, Discriminator loss: 0.00000000
# DONE TRAINING

# %%
#1.c
losses_g = [] # to store generator loss after each epoch
losses_d = [] # to store discriminator loss after each epoch
images = [] # to store images generatd by the generator
optim_g = optim.Adam(generator.parameters(), lr=0.0002,betas=(0.5, 0.999))
optim_d = optim.Adam(discriminator.parameters(), lr=0.0002,betas=(0.5, 0.999))
def update_discriminator(x_real, generator, discriminator, optim_d):
    optim_d.zero_grad()

    # Real pass
    real_output = discriminator(x_real)
    d_loss_real = discriminator_loss(real_output, label_real(real_output.size()[0]))

    # Fake pass
    fake_data = generator(create_noise(sample_size, nz))
    fake_output = discriminator(fake_data)
    d_loss_fake = discriminator_loss(fake_output, label_fake(sample_size))

    loss_D = d_loss_real + d_loss_fake
    loss_D.backward()
    optim_d.step()

    return loss_D.item()

# Function to update the generator
def update_generator(generator, discriminator, optim_g):
    optim_g.zero_grad()

    generated_data = generator(create_noise(sample_size, nz))
    generated_output = discriminator(generated_data)
    loss_G = generator_loss(generated_output, label_real(sample_size))

    loss_G.backward()
    optim_g.step()

    return loss_G.item()

for epoch in range(epochs):
    loss_g = 0.0
    loss_d = 0.0
    for bi, data in tqdm(enumerate(train_loader), total=int(len(train_data)/train_loader.batch_size)):

        x = data[0]
        # Update Discriminator
        loss_d += update_discriminator(x, generator, discriminator, optim_d)

        # Update Generator
        loss_g += update_generator(generator, discriminator, optim_g)
        
    # create the final fake image for the epoch
    generated_img = generator(noise).cpu().detach()
    
    # make the images as grid
    generated_img = make_grid(generated_img)
    
    # visualize generated images
    if (epoch + 1) % 5 == 0:
        plt.imshow(generated_img.permute(1, 2, 0))
        plt.title(f'epoch {epoch+1}')
        plt.axis('off')
        # plt.show()
    
    # save the generated torch tensor models to disk
    save_generator_image(generated_img, f"output_new/gen_img{epoch+1}.png")
    images.append(generated_img)
    epoch_loss_g = loss_g / bi # total generator loss for the epoch
    epoch_loss_d = loss_d / bi # total discriminator loss for the epoch
    losses_g.append(epoch_loss_g)
    losses_d.append(epoch_loss_d)
    
    print(f"Epoch {epoch+1} of {epochs}")
    print(f"Generator loss: {epoch_loss_g:.8f}, Discriminator loss: {epoch_loss_d:.8f}")
# Out:
# 118it [00:04, 24.06it/s]
# Epoch 1 of 100
# Generator loss: 0.85682470, Discriminator loss: 1.20153933
# 118it [00:04, 24.77it/s]
# Epoch 2 of 100
# Generator loss: 1.49769840, Discriminator loss: 0.77575544
# 118it [00:05, 23.57it/s]
# Epoch 3 of 100
# Generator loss: 2.74613437, Discriminator loss: 0.63551307
# 118it [00:04, 24.00it/s]
# Epoch 4 of 100
# Generator loss: 2.86883369, Discriminator loss: 0.58983054
# 118it [00:04, 24.68it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 5 of 100
# Generator loss: 3.45866608, Discriminator loss: 0.65065478
# 118it [00:04, 24.71it/s]
# Epoch 6 of 100
# Generator loss: 3.68309250, Discriminator loss: 0.57929098
# 118it [00:04, 24.51it/s]
# Epoch 7 of 100
# Generator loss: 3.12474958, Discriminator loss: 0.58857305
# 118it [00:04, 24.83it/s]
# Epoch 8 of 100
# Generator loss: 3.65021446, Discriminator loss: 0.54091094
# 118it [00:04, 24.79it/s]
# Epoch 9 of 100
# Generator loss: 3.42846675, Discriminator loss: 0.48378518
# 118it [00:04, 24.86it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 10 of 100
# Generator loss: 2.95803184, Discriminator loss: 0.67328174
# 118it [00:04, 24.45it/s]
# Epoch 11 of 100
# Generator loss: 3.08860408, Discriminator loss: 0.54780716
# 118it [00:04, 24.62it/s]
# Epoch 12 of 100
# Generator loss: 3.18622310, Discriminator loss: 0.53944381
# 118it [00:04, 24.74it/s]
# Epoch 13 of 100
# Generator loss: 3.23329772, Discriminator loss: 0.52277189
# 118it [00:04, 24.43it/s]
# Epoch 14 of 100
# Generator loss: 3.40498511, Discriminator loss: 0.49030111
# 118it [00:04, 24.06it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 15 of 100
# Generator loss: 3.18230949, Discriminator loss: 0.43922207
# 118it [00:04, 24.47it/s]
# Epoch 16 of 100
# Generator loss: 3.18062109, Discriminator loss: 0.43483852
# 118it [00:04, 24.36it/s]
# Epoch 17 of 100
# Generator loss: 3.00940478, Discriminator loss: 0.39237722
# 118it [00:04, 24.36it/s]
# Epoch 18 of 100
# Generator loss: 3.04196137, Discriminator loss: 0.36751315
# 118it [00:04, 24.58it/s]
# Epoch 19 of 100
# Generator loss: 2.93256079, Discriminator loss: 0.39360146
# 118it [00:04, 24.58it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 20 of 100
# Generator loss: 2.93433253, Discriminator loss: 0.39538248
# 118it [00:04, 24.38it/s]
# Epoch 21 of 100
# Generator loss: 2.84299132, Discriminator loss: 0.38922903
# 118it [00:04, 24.72it/s]
# Epoch 22 of 100
# Generator loss: 2.86345747, Discriminator loss: 0.35877124
# 118it [00:04, 24.70it/s]
# Epoch 23 of 100
# Generator loss: 2.82492239, Discriminator loss: 0.38149740
# 118it [00:04, 24.05it/s]
# Epoch 24 of 100
# Generator loss: 2.87767240, Discriminator loss: 0.36823980
# 118it [00:04, 24.68it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 25 of 100
# Generator loss: 2.74672268, Discriminator loss: 0.43462791
# 118it [00:04, 24.32it/s]
# Epoch 26 of 100
# Generator loss: 2.65098817, Discriminator loss: 0.43766203
# 118it [00:04, 24.36it/s]
# Epoch 27 of 100
# Generator loss: 2.51514452, Discriminator loss: 0.46863220
# 118it [00:04, 24.24it/s]
# Epoch 28 of 100
# Generator loss: 2.42077492, Discriminator loss: 0.54939518
# 118it [00:04, 24.42it/s]
# Epoch 29 of 100
# Generator loss: 2.25112542, Discriminator loss: 0.57782630
# 118it [00:04, 24.43it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 30 of 100
# Generator loss: 2.28682469, Discriminator loss: 0.59815689
# 118it [00:05, 22.77it/s]
# Epoch 31 of 100
# Generator loss: 2.50192184, Discriminator loss: 0.56310759
# 118it [00:04, 24.44it/s]
# Epoch 32 of 100
# Generator loss: 2.30215334, Discriminator loss: 0.59483040
# 118it [00:05, 22.24it/s]
# Epoch 33 of 100
# Generator loss: 2.23401565, Discriminator loss: 0.61958391
# 118it [00:05, 23.49it/s]
# Epoch 34 of 100
# Generator loss: 2.08340298, Discriminator loss: 0.73344202
# 118it [00:05, 23.22it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 35 of 100
# Generator loss: 1.94292646, Discriminator loss: 0.70329658
# 118it [00:05, 23.15it/s]
# Epoch 36 of 100
# Generator loss: 1.95387186, Discriminator loss: 0.71332987
# 118it [00:05, 22.20it/s]
# Epoch 37 of 100
# Generator loss: 2.03597693, Discriminator loss: 0.68071209
# 118it [00:05, 21.74it/s]
# Epoch 38 of 100
# Generator loss: 2.06952134, Discriminator loss: 0.66718459
# 118it [00:05, 21.67it/s]
# Epoch 39 of 100
# Generator loss: 1.98252139, Discriminator loss: 0.70035884
# 118it [00:05, 20.71it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 40 of 100
# Generator loss: 1.97510791, Discriminator loss: 0.69516260
# 118it [00:05, 20.11it/s]
# Epoch 41 of 100
# Generator loss: 2.03069217, Discriminator loss: 0.67615364
# 118it [00:06, 19.43it/s]
# Epoch 42 of 100
# Generator loss: 1.96540001, Discriminator loss: 0.72663526
# 118it [00:05, 20.20it/s]
# Epoch 43 of 100
# Generator loss: 1.95943670, Discriminator loss: 0.70222800
# 118it [00:05, 20.01it/s]
# Epoch 44 of 100
# Generator loss: 1.91318219, Discriminator loss: 0.73507149
# 118it [00:05, 19.70it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 45 of 100
# Generator loss: 1.84594367, Discriminator loss: 0.76910767
# 118it [00:06, 19.60it/s]
# Epoch 46 of 100
# Generator loss: 1.90679119, Discriminator loss: 0.73043761
# 118it [00:06, 19.65it/s]
# Epoch 47 of 100
# Generator loss: 1.83965613, Discriminator loss: 0.76718156
# 118it [00:06, 19.39it/s]
# Epoch 48 of 100
# Generator loss: 1.80198486, Discriminator loss: 0.78434475
# 118it [00:05, 20.17it/s]
# Epoch 49 of 100
# Generator loss: 1.74576382, Discriminator loss: 0.80280250
# 118it [00:06, 19.53it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 50 of 100
# Generator loss: 1.72935189, Discriminator loss: 0.82553459
# 118it [00:05, 19.82it/s]
# Epoch 51 of 100
# Generator loss: 1.76641761, Discriminator loss: 0.79084206
# 118it [00:05, 19.96it/s]
# Epoch 52 of 100
# Generator loss: 1.71958122, Discriminator loss: 0.81774476
# 118it [00:05, 19.67it/s]
# Epoch 53 of 100
# Generator loss: 1.67880261, Discriminator loss: 0.83716398
# 118it [00:05, 19.95it/s]
# Epoch 54 of 100
# Generator loss: 1.68364197, Discriminator loss: 0.84976459
# 118it [00:05, 20.02it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 55 of 100
# Generator loss: 1.70874068, Discriminator loss: 0.83628248
# 118it [00:06, 19.47it/s]
# Epoch 56 of 100
# Generator loss: 1.67029263, Discriminator loss: 0.86618457
# 118it [00:05, 19.79it/s]
# Epoch 57 of 100
# Generator loss: 1.63445968, Discriminator loss: 0.87732101
# 118it [00:05, 20.09it/s]
# Epoch 58 of 100
# Generator loss: 1.64201179, Discriminator loss: 0.84863004
# 118it [00:05, 20.38it/s]
# Epoch 59 of 100
# Generator loss: 1.63150225, Discriminator loss: 0.86028508
# 118it [00:05, 19.84it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 60 of 100
# Generator loss: 1.68385230, Discriminator loss: 0.84364368
# 118it [00:06, 19.46it/s]
# Epoch 61 of 100
# Generator loss: 1.68586216, Discriminator loss: 0.84031328
# 118it [00:05, 19.87it/s]
# Epoch 62 of 100
# Generator loss: 1.62036644, Discriminator loss: 0.87855337
# 118it [00:05, 20.23it/s]
# Epoch 63 of 100
# Generator loss: 1.62257591, Discriminator loss: 0.85592449
# 118it [00:05, 20.10it/s]
# Epoch 64 of 100
# Generator loss: 1.67664442, Discriminator loss: 0.86174055
# 118it [00:05, 19.97it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 65 of 100
# Generator loss: 1.67311045, Discriminator loss: 0.85762734
# 118it [00:05, 19.87it/s]
# Epoch 66 of 100
# Generator loss: 1.61990051, Discriminator loss: 0.85860414
# 118it [00:05, 19.72it/s]
# Epoch 67 of 100
# Generator loss: 1.65682595, Discriminator loss: 0.86879636
# 118it [00:05, 20.04it/s]
# Epoch 68 of 100
# Generator loss: 1.63185459, Discriminator loss: 0.87148970
# 118it [00:06, 19.58it/s]
# Epoch 69 of 100
# Generator loss: 1.63447148, Discriminator loss: 0.83769979
# 118it [00:05, 19.97it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 70 of 100
# Generator loss: 1.65039162, Discriminator loss: 0.86260990
# 118it [00:05, 19.96it/s]
# Epoch 71 of 100
# Generator loss: 1.63556420, Discriminator loss: 0.84703454
# 118it [00:06, 19.55it/s]
# Epoch 72 of 100
# Generator loss: 1.66059043, Discriminator loss: 0.83373815
# 118it [00:05, 19.68it/s]
# Epoch 73 of 100
# Generator loss: 1.60980508, Discriminator loss: 0.86290040
# 118it [00:05, 20.06it/s]
# Epoch 74 of 100
# Generator loss: 1.61245764, Discriminator loss: 0.87716404
# 118it [00:06, 19.62it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 75 of 100
# Generator loss: 1.57163241, Discriminator loss: 0.88084735
# 118it [00:05, 19.92it/s]
# Epoch 76 of 100
# Generator loss: 1.54353691, Discriminator loss: 0.89031206
# 118it [00:06, 19.25it/s]
# Epoch 77 of 100
# Generator loss: 1.54089530, Discriminator loss: 0.89088084
# 118it [00:05, 19.84it/s]
# Epoch 78 of 100
# Generator loss: 1.55822714, Discriminator loss: 0.90152789
# 118it [00:05, 19.99it/s]
# Epoch 79 of 100
# Generator loss: 1.57064716, Discriminator loss: 0.88709573
# 118it [00:06, 19.65it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 80 of 100
# Generator loss: 1.57470670, Discriminator loss: 0.88495442
# 118it [00:05, 19.98it/s]
# Epoch 81 of 100
# Generator loss: 1.58125962, Discriminator loss: 0.87805547
# 118it [00:05, 19.90it/s]
# Epoch 82 of 100
# Generator loss: 1.57751317, Discriminator loss: 0.89166823
# 118it [00:05, 19.70it/s]
# Epoch 83 of 100
# Generator loss: 1.50693266, Discriminator loss: 0.91656526
# 118it [00:05, 20.15it/s]
# Epoch 84 of 100
# Generator loss: 1.49987026, Discriminator loss: 0.92781435
# 118it [00:06, 19.29it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 85 of 100
# Generator loss: 1.48457604, Discriminator loss: 0.93909932
# 118it [00:05, 19.99it/s]
# Epoch 86 of 100
# Generator loss: 1.50634906, Discriminator loss: 0.91832713
# 118it [00:06, 19.65it/s]
# Epoch 87 of 100
# Generator loss: 1.50092175, Discriminator loss: 0.92025541
# 118it [00:06, 19.54it/s]
# Epoch 88 of 100
# Generator loss: 1.50005565, Discriminator loss: 0.93913539
# 118it [00:05, 19.78it/s]
# Epoch 89 of 100
# Generator loss: 1.43675046, Discriminator loss: 0.95726808
# 118it [00:05, 20.21it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 90 of 100
# Generator loss: 1.47243830, Discriminator loss: 0.93807053
# 118it [00:05, 20.33it/s]
# Epoch 91 of 100
# Generator loss: 1.47789903, Discriminator loss: 0.93561952
# 118it [00:05, 20.11it/s]
# Epoch 92 of 100
# Generator loss: 1.47876209, Discriminator loss: 0.93788100
# 118it [00:05, 20.30it/s]
# Epoch 93 of 100
# Generator loss: 1.49422476, Discriminator loss: 0.94325504
# 118it [00:05, 20.38it/s]
# Epoch 94 of 100
# Generator loss: 1.44320439, Discriminator loss: 0.94440013
# 118it [00:05, 20.34it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 95 of 100
# Generator loss: 1.46912933, Discriminator loss: 0.94599027
# 118it [00:05, 19.86it/s]
# Epoch 96 of 100
# Generator loss: 1.43881184, Discriminator loss: 0.95460357
# 118it [00:05, 19.72it/s]
# Epoch 97 of 100
# Generator loss: 1.46436792, Discriminator loss: 0.93788788
# 118it [00:05, 20.06it/s]
# Epoch 98 of 100
# Generator loss: 1.45862579, Discriminator loss: 0.93006164
# 118it [00:05, 19.68it/s]
# Epoch 99 of 100
# Generator loss: 1.46087871, Discriminator loss: 0.95260002
# 118it [00:05, 20.55it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 100 of 100
# Generator loss: 1.44059298, Discriminator loss: 0.96305749
# DONE TRAINING

# %%
print('DONE TRAINING')
torch.save(generator.state_dict(), 'output_new/generator.pth')

# save the generated images as GIF file
imgs = [np.array(to_pil_image(img)) for img in images]
imageio.mimsave('output_new/generator_images.gif', imgs)

# plot and save the generator and discriminator loss
plt.figure()
plt.plot(losses_g, label='Generator loss')
plt.plot(losses_d, label='Discriminator Loss')
plt.legend()
plt.savefig('output_new/loss.png')
# Out:
# DONE TRAINING

# %%
#1.c
noise = create_noise(sample_size, nz)
losses_g = [] # to store generator loss after each epoch
losses_d = [] # to store discriminator loss after each epoch
images = [] # to store images generatd by the generator
optim_g = optim.Adam(generator.parameters(), lr=0.0002,betas=(0.5, 0.999))
optim_d = optim.Adam(discriminator.parameters(), lr=0.0002,betas=(0.5, 0.999))
def update_discriminator(x_real, generator, discriminator, optim_d):
    optim_d.zero_grad()

    # Real pass
    real_output = discriminator(x_real)
    d_loss_real = discriminator_loss(real_output, label_real(real_output.size()[0]))

    # Fake pass
    fake_data = generator(create_noise(sample_size, nz))
    fake_output = discriminator(fake_data)
    d_loss_fake = discriminator_loss(fake_output, label_fake(sample_size))

    loss_D = d_loss_real + d_loss_fake
    loss_D.backward()
    optim_d.step()

    return loss_D.item()

# Function to update the generator
def update_generator(generator, discriminator, optim_g):
    optim_g.zero_grad()

    generated_data = generator(create_noise(sample_size, nz))
    generated_output = discriminator(generated_data)
    loss_G = generator_loss(generated_output, label_real(sample_size))

    loss_G.backward()
    optim_g.step()

    return loss_G.item()

for epoch in range(epochs):
    loss_g = 0.0
    loss_d = 0.0
    for bi, data in tqdm(enumerate(train_loader), total=int(len(train_data)/train_loader.batch_size)):

        x = data[0]
        # Update Discriminator
        loss_d += update_discriminator(x, generator, discriminator, optim_d)

        # Update Generator
        loss_g += update_generator(generator, discriminator, optim_g)
        
    # create the final fake image for the epoch
    generated_img = generator(noise).cpu().detach()
    
    # make the images as grid
    generated_img = make_grid(generated_img)
    
    # visualize generated images
    if (epoch + 1) % 5 == 0:
        plt.imshow(generated_img.permute(1, 2, 0))
        plt.title(f'epoch {epoch+1}')
        plt.axis('off')
        # plt.show()
    
    # save the generated torch tensor models to disk
    save_generator_image(generated_img, f"output_new/gen_img{epoch+1}.png")
    images.append(generated_img)
    epoch_loss_g = loss_g / bi # total generator loss for the epoch
    epoch_loss_d = loss_d / bi # total discriminator loss for the epoch
    losses_g.append(epoch_loss_g)
    losses_d.append(epoch_loss_d)
    
    print(f"Epoch {epoch+1} of {epochs}")
    print(f"Generator loss: {epoch_loss_g:.8f}, Discriminator loss: {epoch_loss_d:.8f}")
# Out:
# 118it [00:04, 23.69it/s]
# Epoch 1 of 100
# Generator loss: 1.37664839, Discriminator loss: 1.00548926
# 118it [00:05, 21.59it/s]
# Epoch 2 of 100
# Generator loss: 1.37926624, Discriminator loss: 0.99798986
#  40%|████████████████▊                         | 47/117 [00:02<00:03, 21.23it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 46
#      44 x = data[0]
#      45 # Update Discriminator
# ---> 46 loss_d += update_discriminator(x, generator, discriminator, optim_d)
#      48 # Update Generator
#      49 loss_g += update_generator(generator, discriminator, optim_g)
#
# Cell In[34], line 21, in update_discriminator(x_real, generator, discriminator, optim_d)
#      18 d_loss_fake = discriminator_loss(fake_output, label_fake(sample_size))
#      20 loss_D = d_loss_real + d_loss_fake
# ---> 21 loss_D.backward()
#      22 optim_d.step()
#      24 return loss_D.item()
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/autograd/__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:
